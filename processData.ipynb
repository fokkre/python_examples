# %%
import searchpatientlist

random_ids = searchpatientlist.get_random_ids(10)

print(random_ids)
print(searchpatientlist.get_results_by_id(random_ids[0]))

# for id in random_ids:
#     print(f"Patient ID:{id}")
#     results = searchpatientlist.get_results_by_id(id)
#     print(results[0])
#     print(results[1])
#     print("")
# Out:
# ['883270', '902976', '90312', '868202', '90944601', '904647', '91805', '862722', '88119002', '8810955']
# ...
